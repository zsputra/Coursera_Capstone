# %% [markdown]
# # Clustering Tuscaloosa, Montgomery, Brimingham  Restaurants in Alabama

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Background

# %% [markdown]
# This is the capstone project of IBM Data Science Professional Certificate. In this project, I will use the Foursquare location data to explore venues in three city  Tuscaloosa, Montgomery, Brimingham in Alabama, and use Zomato api to get all the restaurants in these three city, and then come up with a problem that I can use the Foursquare location data to solve.

# %% [markdown]
# ### 1.2 Problem

# %% [markdown]
# I will explore these restaurants and try to answer the question: "Where is the appropirate restaurant to invest in these three city?".

# %% [markdown]
# ### 1.3 Interest

# %% [markdown]
# Alabama, also known as the Yellowhammer State, the Cotton State, and the Heart of Dixie, is considered to be the thirtieth largest state by area. What the state has become today is a product of the economic hardship it suffered in the past. In terms of business development, Alabama has many reasons to be proud of. Alabama is a hub for medicine and automotive manufacturing, with recent successes ranging from Remington to Polaris. Companies such as Airbus, Hyundai, and Mercedes-Benz locating plants in the state demonstrate how pro-business Alabama can be for big companies. A new study reveals that Alabama is likewise an attractive destination for small business entrepreneurs and owners. So invest in a restaurant in this city is an attractive idea for anyone who want to invest.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# To solve the problem, i'll use the <b>Foursquare API</b> to explore venue surrounding each restaurants. Foursquare outlines these high-level venue categories with more sub-categories.
#
#     Arts & Entertainment (4d4b7104d754a06370d81259)
#     College & University (4d4b7105d754a06372d81259)
#     Event (4d4b7105d754a06373d81259)
#     Food (4d4b7105d754a06374d81259)
#     Nightlife Spot (4d4b7105d754a06376d81259)
#     Outdoors & Recreation (4d4b7105d754a06377d81259)
#     Professional & Other Places (4d4b7105d754a06375d81259)
#     Residence (4e67e38e036454776db1fb3a)
#     Shop & Service (4d4b7105d754a06378d81259)
#     Travel & Transport (4d4b7105d754a06379d81259)
#
# We’ll be querying the number of venues in each category in a 1000m radius around each restaurants. This radius was chosen because 1000m is a reasonable walking distance.

# %% [markdown]
# Then i'll use the <b>Zomato API</b> to get the restaurants data from each city, Tuscaloosa, Montgomery, Brimingham in Alabama, using their coordinate.

# %% [markdown]
#     Tuscaloosa (33.2098,-87.5692)
#     Montgomery (32.3792, -86.3077)
#     Brimingham (33.5186, -86.8104)

# %%
import pandas as pd
import numpy as np
import folium
import json
import requests
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim 
import pprint
import matplotlib.pyplot as plt
import seaborn as sns

CLIENT_ID = "FFEFW3ZL0BZ4UXSVKSI0XSGC3FGI30HCTRQ5GPZLSJUR0GSI"
CLIENT_SECRET = "NO3YYEJ35KLKMMAAEWLKRQOCEV0VG35RK5ENJX4NKR4DZAOG"
VERSION = "20180604"
#key zomatto
key = "509c6a5ac1f97d60b55b4dc3da482107"

# %% [markdown]
# ### Tuscaloosa restaurants

# %%
tuscaloosa_restaurants = pd.DataFrame()
tuscaloosa_coord = (33.2098,-87.5692)
pages = [0,20,40,60,80]
for page in pages:
    uris = "https://developers.zomato.com/api/v2.1/search?lat={}&lon={}&apikey={}&radius={}&start={}&count={}".format(tuscaloosa_coord[0],tuscaloosa_coord[1],key,10000,page,20)
    request_ = requests.get(uris).json()
    csv_ = json_normalize(request_['restaurants'])
    tuscaloosa_restaurants = tuscaloosa_restaurants.append(csv_)

# %% [markdown]
# Clean the dataframe

# %%
#Reset the index of the dataframe, becuase the dataframe is the result of the append method
tuscaloosa_restaurants.reset_index(inplace=True, drop=True)
#The feature that i'll use
feature = ['restaurant.name','restaurant.cuisines','restaurant.average_cost_for_two','restaurant.user_rating.aggregate_rating','restaurant.timings','restaurant.all_reviews_count',
           'restaurant.user_rating.votes','restaurant.location.latitude','restaurant.location.longitude']
#Only use the feature that i consider as more valuable
tuscaloosa_restaurants = tuscaloosa_restaurants[feature]
#Convert some of the features that supose to be fload
col_to_convert_to_float = ['restaurant.user_rating.aggregate_rating','restaurant.user_rating.votes', 'restaurant.location.latitude', 'restaurant.location.longitude']
for col in col_to_convert_to_float:
    tuscaloosa_restaurants[col] = tuscaloosa_restaurants[col].astype(float)
#make a coordinate column
tuscaloosa_restaurants['coordinate'] = [(i,j) for i, j in zip(tuscaloosa_restaurants['restaurant.location.latitude'], tuscaloosa_restaurants['restaurant.location.longitude'])]

# %%
tuscaloosa_restaurants.head()
# Out:
#            restaurant.name         restaurant.cuisines  \
# 0                City Cafe    Diner, Seafood, Southern
# 1  Swen Chinese Restaurant                     Chinese
# 2   DePalma's Italian Cafe                     Italian
# 3              Cypress Inn    American, Seafood, Steak
# 4     Mugshots Grill & Bar  American, Burger, Bar Food
#
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               10                                      3.8
# 1                               25                                      3.6
# 2                               40                                      3.8
# 3                               40                                      3.5
# 4                               10                                      3.6
#
#                                   restaurant.timings  \
# 0             (Sun, Sat), Breakfast, Lunch (Mon-Fri)
# 1  11 AM to 10 PM (Mon, Tue, Wed, Thu, Sun), 11 A...
# 2  Closed (Mon),11 AM to 10 PM (Tue-Thu),11 AM to...
# 3  11 AM to 9 PM (Mon-Thu), 11 AM to 10 PM (Fri-S...
# 4  11 AM to 10 PM (Mon-Thu),11 AM to 11 PM (Fri-S...
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                            38                         288.0
# 1                            37                         192.0
# 2                            93                         428.0
# 3                            60                         303.0
# 4                            74                         295.0
#
#    restaurant.location.latitude  restaurant.location.longitude  \
# 0                      33.21810                      -87.57830
# 1                      33.21082                      -87.55275
# 2                      33.21040                      -87.56710
# 3                      33.22921                      -87.52863
# 4                      33.20960                      -87.56810
#
#               coordinate
# 0    (33.2181, -87.5783)
# 1  (33.21082, -87.55275)
# 2    (33.2104, -87.5671)
# 3  (33.22921, -87.52863)
# 4    (33.2096, -87.5681)

# %% [markdown]
# ### Montgomery restaurants

# %%
montgomery_restaurants = pd.DataFrame()
montgomery_coord = (32.3792, -86.3077)
pages = [0,20,40,60,80]
for page in pages:
    uris = "https://developers.zomato.com/api/v2.1/search?lat={}&lon={}&apikey={}&radius={}&start={}&count={}".format(montgomery_coord[0],montgomery_coord[1],key,10000,page,20)
    request_ = requests.get(uris).json()
    csv_ = json_normalize(request_['restaurants'])
    montgomery_restaurants = montgomery_restaurants.append(csv_)

# %% [markdown]
# Clean the data with the same prosedure as Tuscaloosa data

# %%
montgomery_restaurants.reset_index(inplace=True, drop=True)
feature = ['restaurant.name','restaurant.cuisines','restaurant.average_cost_for_two','restaurant.user_rating.aggregate_rating','restaurant.timings','restaurant.all_reviews_count',
           'restaurant.user_rating.votes','restaurant.location.latitude','restaurant.location.longitude']
montgomery_restaurants = montgomery_restaurants[feature]
col_to_convert_to_float = ['restaurant.user_rating.aggregate_rating','restaurant.user_rating.votes', 'restaurant.location.latitude', 'restaurant.location.longitude']
for col in col_to_convert_to_float:
    montgomery_restaurants[col] = montgomery_restaurants[col].astype(float)
montgomery_restaurants['coordinate'] = [(i,j) for i, j in zip(montgomery_restaurants['restaurant.location.latitude'], montgomery_restaurants['restaurant.location.longitude'])]

# %%
montgomery_restaurants.head()
# Out:
#             restaurant.name       restaurant.cuisines  \
# 0                     Sa Za            Italian, Pizza
# 1                Sushi Cafe           Japanese, Sushi
# 2       Lek's Railroad Thai        Asian, Sushi, Thai
# 3             Wishbone Cafe  Sandwich, Seafood, Cajun
# 4  Dreamland BBQ Montgomery     BBQ, Burger, Sandwich
#
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               40                                      4.2
# 1                               25                                      4.9
# 2                               25                                      4.5
# 3                               25                                      4.5
# 4                               25                                      4.4
#
#                                   restaurant.timings  \
# 0  11 AM to 2 PM, 5 PM to 10 PM (Mon-Thu), 11 AM ...
# 1  11 AM to 2:30 PM, 5 PM to 9:30 PM (Mon-Fri),5 ...
# 2  11 AM to 9 PM (Mon-Thu),11 AM to 10 PM (Fri-Sa...
# 3                      (Sun),Lunch, Dinner (Mon-Sat)
# 4  10 AM to 9 PM (Mon-Thu), 10 AM to 10 PM (Fri-S...
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                           101                         262.0
# 1                            45                         139.0
# 2                            51                         230.0
# 3                            59                         150.0
# 4                            59                         198.0
#
#    restaurant.location.latitude  restaurant.location.longitude  \
# 0                     32.379390                     -86.311010
# 1                     32.355817                     -86.264911
# 2                     32.380500                     -86.314000
# 3                     32.382271                     -86.171836
# 4                     32.380860                     -86.310830
#
#                 coordinate
# 0    (32.37939, -86.31101)
# 1  (32.355817, -86.264911)
# 2       (32.3805, -86.314)
# 3  (32.382271, -86.171836)
# 4    (32.38086, -86.31083)

# %% [markdown]
# ### Brimingham restaurants

# %%
brimingham_restaurants = pd.DataFrame()
pages = [0,20,40,60,80]
brimingham_coord = (33.5186,-86.8104)
for page in pages:
    uris = "https://developers.zomato.com/api/v2.1/search?lat={}&lon={}&apikey={}&radius={}&start={}&count={}".format(brimingham_coord[0],brimingham_coord[1],key,10000,page,20)
    request_ = requests.get(uris).json()
    csv_ = json_normalize(request_['restaurants'])
    brimingham_restaurants = brimingham_restaurants.append(csv_)

# %% [markdown]
# Clean the data

# %%
brimingham_restaurants.reset_index(inplace=True, drop=True)
feature = ['restaurant.name','restaurant.cuisines','restaurant.average_cost_for_two','restaurant.user_rating.aggregate_rating','restaurant.timings','restaurant.all_reviews_count',
           'restaurant.user_rating.votes','restaurant.location.latitude','restaurant.location.longitude']
brimingham_restaurants = brimingham_restaurants[feature]
col_to_convert_to_float = ['restaurant.user_rating.aggregate_rating','restaurant.user_rating.votes', 'restaurant.location.latitude', 'restaurant.location.longitude']
for col in col_to_convert_to_float:
    brimingham_restaurants[col] = brimingham_restaurants[col].astype(float)
brimingham_restaurants['coordinate'] = [(i,j) for i, j in zip(brimingham_restaurants['restaurant.location.latitude'], brimingham_restaurants['restaurant.location.longitude'])]

# %%
brimingham_restaurants.head()
# Out:
#                       restaurant.name                  restaurant.cuisines  \
# 0         Bottega Restaurant and Cafe  Italian, Cafe, Pizza, Mediterranean
# 1                         GianMarco's     Italian, Mediterranean, Southern
# 2                          Surin West                   Asian, Sushi, Thai
# 3                           SAW's BBQ                        BBQ, Sandwich
# 4  Joe's Italian Pizza, Pasta & Caffe             Desserts, Italian, Pizza
#
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               40                                      4.9
# 1                               40                                      4.9
# 2                               25                                      4.6
# 3                               25                                      4.7
# 4                               25                                      4.7
#
#                                   restaurant.timings  \
# 0         11 AM to 10 PM (Tue-Sat), Mon & Sun Closed
# 1  5 PM to 10 PM (Mon, Tue, Sat), 11 AM to 2 PM, ...
# 2  11 AM to 9:30 PM (Mon-Thu), 11 AM to 10:30 PM ...
# 3                11 AM to 8 PM (Mon-Sat), Sun Closed
# 4                         10:30 AM to 9 PM (Mon-Sun)
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                            98                         814.0
# 1                           161                         826.0
# 2                           137                         840.0
# 3                           175                         740.0
# 4                           314                         739.0
#
#    restaurant.location.latitude  restaurant.location.longitude  \
# 0                     33.502341                     -86.789783
# 1                     33.463387                     -86.812239
# 2                     33.500760                     -86.795540
# 3                     33.473800                     -86.808290
# 4                     33.259583                     -86.796361
#
#                 coordinate
# 0  (33.502341, -86.789783)
# 1  (33.463387, -86.812239)
# 2    (33.50076, -86.79554)
# 3     (33.4738, -86.80829)
# 4  (33.259583, -86.796361)

# %% [markdown]
# Get the venues for each city using Foursquare API

# %%
#The list category of venues
venue_cat = ['Arts_Entertainment', 'College_University', 'Event', 'Nightlife_Spot', 'Outdoors_Recreation',
            'Professional_n_Other_Places', 'Shop_Service', 'Travel_Transport', 'Residence']
#The Id for each venue category
venue_cat_id = ['4d4b7104d754a06370d81259','4d4b7105d754a06372d81259','4d4b7105d754a06373d81259', '4d4b7105d754a06376d81259','4d4b7105d754a06377d81259','4d4b7105d754a06375d81259','4d4b7105d754a06378d81259','4d4b7105d754a06379d81259', '4e67e38e036454776db1fb3a']


ra = []

#three towns coordinates (tusaloosa, montgomary, brimingham)
coord = [(33.2098,-87.5692), (32.3792, -86.3077), (33.5186, -86.8104)]

#get the venue for each category and for each city, with radius 20000m
for (i,j) in coord:
    reqs1 = []
    for cat, cat_id in zip(venue_cat,venue_cat_id):
            url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            i, 
            j, 
            20000,
            cat_id)
            results = requests.get(url).json()
            reqs1.append(results)
    ra.append(reqs1)

# %% [markdown]
# Group the venues for each city

# %%
ra[0][3]
# Out:
# {'meta': {'code': 200, 'requestId': '5dc13bee02a1720028b9a062'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Tuscaloosa',
#   'headerFullLocation': 'Tuscaloosa',
#   'headerLocationGranularity': 'city',
#   'query': 'nightlife',
#   'totalResults': 35,
#   'suggestedBounds': {'ne': {'lat': 33.38980018000018,
#     'lng': -87.35446305399667},
#    'sw': {'lat': 33.02979981999982, 'lng': -87.78393694600332}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52da0363498ee92698ffd8ad',
#        'name': 'The Avenue Pub',
#        'location': {'address': '405 23rd Ave',
#         'lat': 33.21098692413535,
#         'lng': -87.56698565086404,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21098692413535,
#           'lng': -87.56698565086404}],
#         'distance': 244,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['405 23rd Ave',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52da0363498ee92698ffd8ad-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d32902ef8c9224be5b1b2d2',
#        'name': '5 Restaurant',
#        'location': {'address': '2324 6th St',
#         'lat': 33.209294250913274,
#         'lng': -87.56744295358658,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.209294250913274,
#           'lng': -87.56744295358658}],
#         'distance': 173,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2324 6th St',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d32902ef8c9224be5b1b2d2-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548a2836498e972164111139',
#        'name': 'Loosa Brews',
#        'location': {'address': '412 20th Avenue',
#         'lat': 33.21182270000001,
#         'lng': -87.5632931,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21182270000001,
#           'lng': -87.5632931}],
#         'distance': 594,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['412 20th Avenue',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '506727777'}},
#       'referralId': 'e-0-548a2836498e972164111139-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b495a05f964a5201d6e26e3',
#        'name': 'Alcove',
#        'location': {'address': '730 22nd Ave',
#         'lat': 33.20788260168125,
#         'lng': -87.56469156857084,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.20788260168125,
#           'lng': -87.56469156857084}],
#         'distance': 471,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['730 22nd Ave',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b495a05f964a5201d6e26e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527ff3ff11d22bbf128ff873',
#        'name': 'Black Warrior Brewing Company',
#        'location': {'address': '2216 University Blvd',
#         'lat': 33.21061078005374,
#         'lng': -87.56635259576518,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21061078005374,
#           'lng': -87.56635259576518}],
#         'distance': 280,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2216 University Blvd',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91734483'}},
#       'referralId': 'e-0-527ff3ff11d22bbf128ff873-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4965a7f964a5200f6f26e3',
#        'name': 'Catch 22',
#        'location': {'lat': 33.209076797848226,
#         'lng': -87.56759917101748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.209076797848226,
#           'lng': -87.56759917101748}],
#         'distance': 169,
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['Tuscaloosa, AL', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4965a7f964a5200f6f26e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b3bf681fc9e94002ca879e2',
#        'name': 'World of Beer',
#        'location': {'address': '2107 University Blvd',
#         'crossStreet': '21st Street',
#         'lat': 33.210633,
#         'lng': -87.564607,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.210633,
#           'lng': -87.564607}],
#         'distance': 437,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2107 University Blvd (21st Street)',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '503817811'}},
#       'referralId': 'e-0-5b3bf681fc9e94002ca879e2-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b43c362f964a520f4e825e3',
#        'name': "Wilhagan's",
#        'location': {'address': '2209 4th St',
#         'crossStreet': '23rd Ave',
#         'lat': 33.21118657103145,
#         'lng': -87.56652031486793,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21118657103145,
#           'lng': -87.56652031486793}],
#         'distance': 293,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2209 4th St (23rd Ave)',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b43c362f964a520f4e825e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50df6b90e4b083ca7152dbec',
#        'name': 'Druid City Brewing Company',
#        'location': {'address': '907 14th St',
#         'lat': 33.1999796354279,
#         'lng': -87.54504997746598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.1999796354279,
#           'lng': -87.54504997746598}],
#         'distance': 2500,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['907 14th St',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50df6b90e4b083ca7152dbec-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4efd41e4b8f787cacea3c593',
#        'name': 'Five Bar',
#        'location': {'address': '2324 6th St',
#         'lat': 33.20908776323985,
#         'lng': -87.56757110021833,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.20908776323985,
#           'lng': -87.56757110021833}],
#         'distance': 171,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2324 6th St',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '65695748'}},
#       'referralId': 'e-0-4efd41e4b8f787cacea3c593-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56aff0b3498ec155d3cbc033',
#        'name': "PYRO'S Fire Fresh Pizza",
#        'location': {'address': '1320 McFarland Blvd E',
#         'lat': 33.200461062820324,
#         'lng': -87.52690696878201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.200461062820324,
#           'lng': -87.52690696878201}],
#         'distance': 4074,
#         'postalCode': '35404',
#         'cc': 'US',
#         'neighborhood': 'Legacy Park',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1320 McFarland Blvd E',
#          'Tuscaloosa, AL 35404',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56aff0b3498ec155d3cbc033-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4d9cdbf964a520d1d426e3',
#        'name': 'Innisfree',
#        'location': {'address': '1925 University Blvd',
#         'lat': 33.21104589401324,
#         'lng': -87.56251982156758,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21104589401324,
#           'lng': -87.56251982156758}],
#         'distance': 637,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1925 University Blvd',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4d9cdbf964a520d1d426e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d38eec14730370401056ea5',
#        'name': 'Rounders On The Strip',
#        'location': {'address': '1137 University Blvd',
#         'lat': 33.210887855580616,
#         'lng': -87.55390071787082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.210887855580616,
#           'lng': -87.55390071787082}],
#         'distance': 1430,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1137 University Blvd',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46563999'}},
#       'referralId': 'e-0-4d38eec14730370401056ea5-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b44037ef964a52030f025e3',
#        'name': "Buffalo Phil's",
#        'location': {'address': '1149 University Blvd',
#         'crossStreet': 'at 12th Ave',
#         'lat': 33.21076287823245,
#         'lng': -87.55316822746501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21076287823245,
#           'lng': -87.55316822746501}],
#         'distance': 1496,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1149 University Blvd (at 12th Ave)',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b44037ef964a52030f025e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fdd1aa498e34fa22eed7bc',
#        'name': 'Band of Brothers Brewing Co.',
#        'location': {'address': '1605 23rd Ave',
#         'lat': 33.19833840648084,
#         'lng': -87.56184516409513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.19833840648084,
#           'lng': -87.56184516409513}],
#         'distance': 1448,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1605 23rd Ave',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fdd1aa498e34fa22eed7bc-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4d9c79f964a520c9d426e3',
#        'name': "Gallette's",
#        'location': {'address': '1021 University Blvd',
#         'lat': 33.21038905066993,
#         'lng': -87.5523910581071,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21038905066993,
#           'lng': -87.5523910581071}],
#         'distance': 1566,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1021 University Blvd',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4d9c79f964a520c9d426e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b43ff79f964a520ddef25e3',
#        'name': 'Downtown Pub',
#        'location': {'address': '2427 University Blvd',
#         'crossStreet': 'at Lurleen Wallace Blvd N',
#         'lat': 33.20911245177651,
#         'lng': -87.56943956537447,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.20911245177651,
#           'lng': -87.56943956537447}],
#         'distance': 79,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2427 University Blvd (at Lurleen Wallace Blvd N)',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b43ff79f964a520ddef25e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6babc6f964a52004152ce3',
#        'name': 'Houndstooth',
#        'location': {'address': '1300 University Blvd',
#         'lat': 33.21116746990457,
#         'lng': -87.55460810601035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21116746990457,
#           'lng': -87.55460810601035}],
#         'distance': 1367,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1300 University Blvd',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6babc6f964a52004152ce3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b99bc22f964a5200e8f35e3',
#        'name': 'The Red Shed',
#        'location': {'lat': 33.21063928854015,
#         'lng': -87.5543690128757,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21063928854015,
#           'lng': -87.5543690128757}],
#         'distance': 1384,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['Tuscaloosa, AL 35401', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b99bc22f964a5200e8f35e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4402e8f964a52027f025e3',
#        'name': "Egan's",
#        'location': {'address': '1229 University Blvd',
#         'lat': 33.21094484327904,
#         'lng': -87.55449381378752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21094484327904,
#           'lng': -87.55449381378752}],
#         'distance': 1375,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1229 University Blvd',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4402e8f964a52027f025e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4fe4eef964a520de1827e3',
#        'name': 'Rhythm and Brews',
#        'location': {'address': '2308 4th St',
#         'lat': 33.21131969450196,
#         'lng': -87.56772589076276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21131969450196,
#           'lng': -87.56772589076276}],
#         'distance': 217,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2308 4th St',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4fe4eef964a520de1827e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5fdabcf964a520d7ce29e3',
#        'name': 'Gray Lady',
#        'location': {'address': '521 Greensboro Ave',
#         'crossStreet': '7th St & Greensboro',
#         'lat': 33.20922467011791,
#         'lng': -87.56792590156704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.20922467011791,
#           'lng': -87.56792590156704}],
#         'distance': 134,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['521 Greensboro Ave (7th St & Greensboro)',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5fdabcf964a520d7ce29e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4e8c25f964a52017f126e3',
#        'name': 'Buffalo Wild Wings',
#        'location': {'address': '2710 McFarland Blvd E',
#         'lat': 33.1839295678279,
#         'lng': -87.52679005265242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.1839295678279,
#           'lng': -87.52679005265242}],
#         'distance': 4888,
#         'postalCode': '35405',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2710 McFarland Blvd E',
#          'Tuscaloosa, AL 35405',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14c941735',
#          'name': 'Wings Joint',
#          'pluralName': 'Wings Joints',
#          'shortName': 'Wings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4e8c25f964a52017f126e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7f904bf964a5209c3430e3',
#        'name': 'Bear Trap',
#        'location': {'address': '508 12th Ave',
#         'lat': 33.210588445254274,
#         'lng': -87.55300748797775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.210588445254274,
#           'lng': -87.55300748797775}],
#         'distance': 1510,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['508 12th Ave',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7f904bf964a5209c3430e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdb02ac6ad1a093d891e956',
#        'name': "Bob's Victory Grille",
#        'location': {'address': '1800 McFarland Blvd E Ste 218',
#         'lat': 33.212635,
#         'lng': -87.52409,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.212635,
#           'lng': -87.52409}],
#         'distance': 4213,
#         'postalCode': '35404',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['1800 McFarland Blvd E Ste 218',
#          'Tuscaloosa, AL 35404',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdb02ac6ad1a093d891e956-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b916542f964a520efb833e3',
#        'name': "Big Daddy's Cafe",
#        'location': {'address': '514 Greensboro Ave',
#         'lat': 33.2092525,
#         'lng': -87.5684661,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2092525,
#           'lng': -87.5684661}],
#         'distance': 91,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['514 Greensboro Ave',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b916542f964a520efb833e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba7f3f3f964a52067c139e3',
#        'name': 'Tavern 1831',
#        'location': {'address': '2304 4th St',
#         'lat': 33.211446353288416,
#         'lng': -87.5676441192627,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.211446353288416,
#           'lng': -87.5676441192627}],
#         'distance': 233,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2304 4th St',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba7f3f3f964a52067c139e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdba69e2a3a0f47ad48b0b6',
#        'name': 'Icon',
#        'location': {'address': '516 Greensboro Ave',
#         'lat': 33.20928457960473,
#         'lng': -87.5681435502872,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.20928457960473,
#           'lng': -87.5681435502872}],
#         'distance': 113,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['516 Greensboro Ave',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d8941735',
#          'name': 'Gay Bar',
#          'pluralName': 'Gay Bars',
#          'shortName': 'Gay Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdba69e2a3a0f47ad48b0b6-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b535b7cf964a5200a9927e3',
#        'name': 'Copper Top',
#        'location': {'address': '2300 4th St',
#         'lat': 33.21139684784182,
#         'lng': -87.56753480292991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21139684784182,
#           'lng': -87.56753480292991}],
#         'distance': 235,
#         'postalCode': '35401',
#         'cc': 'US',
#         'city': 'Tuscaloosa',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['2300 4th St',
#          'Tuscaloosa, AL 35401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b535b7cf964a5200a9927e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511ed2ebe4b0b14e1e394e96',
#        'name': "Billy's Sports Grill",
#        'location': {'address': '430 Main Ave',
#         'lat': 33.21893579186762,
#         'lng': -87.57867870697487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21893579186762,
#           'lng': -87.57867870697487}],
#         'distance': 1346,
#         'postalCode': '35476',
#         'cc': 'US',
#         'city': 'Northport',
#         'state': 'AL',
#         'country': 'United States',
#         'formattedAddress': ['430 Main Ave',
#          'Northport, AL 35476',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-511ed2ebe4b0b14e1e394e96-29'}]}]}}

# %%
#convert the address from a list to a string
def concat(x):
    s = x[0]
    for st in x[1:]:
        s += ', '+st
    return s

def city_venues(venue_cat, result_respond):
    result = {}
    for venue, json in zip(venue_cat, result_respond):
        feature = ['categories', 'id', 'location.formattedAddress', 'location.lat', 'location.lng', 'name']
        data1 = pd.DataFrame(columns = feature)
        for rest in json['response']['groups'][0]['items']:
                d = json_normalize(rest['venue'])
                d = d[feature]
                d['categories'] = [data[0]['name'] for data in d['categories']]
                d['location.formattedAddress'] = d['location.formattedAddress'].apply(concat)
                data1 = data1.append(d)
        data1.reset_index(inplace=True, drop = True)
        data1['coordinate'] = [(i,j) for i,j in zip(data1['location.lat'], data1['location.lng'])]
        result[venue] = data1
    return result

Tuscaloosa_venues = city_venues(venue_cat, ra[0])
Montgomery_venues = city_venues(venue_cat, ra[1])
Brimingham_venues = city_venues(venue_cat, ra[2])

# %% [markdown]
#  Measure the distance for every restaurant to every venues for each city

# %% [markdown]
# First we difne the Haversine function to measure the distance between two coordinates

# %%
import math

def haversine(coord1, coord2):
    R = 6372800  # Earth radius in meters
    lat1, lon1 = coord1
    lat2, lon2 = coord2
    
    phi1, phi2 = math.radians(lat1), math.radians(lat2) 
    dphi       = math.radians(lat2 - lat1)
    dlambda    = math.radians(lon2 - lon1)
    
    a = math.sin(dphi/2)**2 + \
        math.cos(phi1)*math.cos(phi2)*math.sin(dlambda/2)**2
    
    return 2*R*math.atan2(math.sqrt(a), math.sqrt(1 - a))

# %% [markdown]
# Then i'll measure the distance for every coordinate restaurant to each city venue from the result above then get the number of each venue category that still inside the 1000m radius and return in it as a list

# %%
def distance(coord, city_venues):
    a = []
    for cat, dataframe in city_venues.items():
            nearest_distance = [haversine(coord, i) for i in dataframe['coordinate']]
            a.append(nearest_distance)
    for i in a:
        i = np.array(i)
    a = pd.DataFrame(a).transpose()
    a = list(a[a<=1000].notnull().sum())
    return a

# %% [markdown]
# Using that function, i'll append the result to each city restaurant dataframe

# %%
lists1 = np.array([distance(coord, Tuscaloosa_venues) for coord in tuscaloosa_restaurants['coordinate']])
new_dataframe1 = pd.DataFrame(lists1, columns = venue_cat)
tuscaloosa_restaurants = pd.concat([tuscaloosa_restaurants, new_dataframe1], axis = 1)

lists2 = np.array([distance(coord, Montgomery_venues) for coord in montgomery_restaurants['coordinate']])
new_dataframe2 = pd.DataFrame(lists2, columns = venue_cat)
montgomery_restaurants = pd.concat([montgomery_restaurants, new_dataframe2], axis = 1)

lists3 = np.array([distance(coord, Brimingham_venues) for coord in brimingham_restaurants['coordinate']])
new_dataframe3 = pd.DataFrame(lists3, columns = venue_cat)
brimingham_restaurants = pd.concat([brimingham_restaurants, new_dataframe3], axis = 1)

# %%
tuscaloosa_restaurants.head()
# Out:
#            restaurant.name         restaurant.cuisines  \
# 0                City Cafe    Diner, Seafood, Southern
# 1  Swen Chinese Restaurant                     Chinese
# 2   DePalma's Italian Cafe                     Italian
# 3              Cypress Inn    American, Seafood, Steak
# 4     Mugshots Grill & Bar  American, Burger, Bar Food
#
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               10                                      3.8
# 1                               25                                      3.6
# 2                               40                                      3.8
# 3                               40                                      3.5
# 4                               10                                      3.6
#
#                                   restaurant.timings  \
# 0             (Sun, Sat), Breakfast, Lunch (Mon-Fri)
# 1  11 AM to 10 PM (Mon, Tue, Wed, Thu, Sun), 11 A...
# 2  Closed (Mon),11 AM to 10 PM (Tue-Thu),11 AM to...
# 3  11 AM to 9 PM (Mon-Thu), 11 AM to 10 PM (Fri-S...
# 4  11 AM to 10 PM (Mon-Thu),11 AM to 11 PM (Fri-S...
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                            38                         288.0
# 1                            37                         192.0
# 2                            93                         428.0
# 3                            60                         303.0
# 4                            74                         295.0
#
#    restaurant.location.latitude  restaurant.location.longitude  \
# 0                      33.21810                      -87.57830
# 1                      33.21082                      -87.55275
# 2                      33.21040                      -87.56710
# 3                      33.22921                      -87.52863
# 4                      33.20960                      -87.56810
#
#               coordinate  Arts_Entertainment  College_University  Event  \
# 0    (33.2181, -87.5783)                   4                   0      1
# 1  (33.21082, -87.55275)                   6                  23      1
# 2    (33.2104, -87.5671)                  11                   0      2
# 3  (33.22921, -87.52863)                   0                   0      0
# 4    (33.2096, -87.5681)                  11                   0      2
#
#    Nightlife_Spot  Outdoors_Recreation  Professional_n_Other_Places  \
# 0               1                    0                            1
# 1               9                    4                            4
# 2              17                    3                            6
# 3               0                    0                            2
# 4              17                    3                            6
#
#    Shop_Service  Travel_Transport  Residence
# 0             0                 2          0
# 1             4                 0          1
# 2             2                 7          1
# 3             0                 0          1
# 4             2                 7          1

# %%
montgomery_restaurants.head()
# Out:
#             restaurant.name       restaurant.cuisines  \
# 0                     Sa Za            Italian, Pizza
# 1                Sushi Cafe           Japanese, Sushi
# 2       Lek's Railroad Thai        Asian, Sushi, Thai
# 3             Wishbone Cafe  Sandwich, Seafood, Cajun
# 4  Dreamland BBQ Montgomery     BBQ, Burger, Sandwich
#
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               40                                      4.2
# 1                               25                                      4.9
# 2                               25                                      4.5
# 3                               25                                      4.5
# 4                               25                                      4.4
#
#                                   restaurant.timings  \
# 0  11 AM to 2 PM, 5 PM to 10 PM (Mon-Thu), 11 AM ...
# 1  11 AM to 2:30 PM, 5 PM to 9:30 PM (Mon-Fri),5 ...
# 2  11 AM to 9 PM (Mon-Thu),11 AM to 10 PM (Fri-Sa...
# 3                      (Sun),Lunch, Dinner (Mon-Sat)
# 4  10 AM to 9 PM (Mon-Thu), 10 AM to 10 PM (Fri-S...
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                           101                         262.0
# 1                            45                         139.0
# 2                            51                         230.0
# 3                            59                         150.0
# 4                            59                         198.0
#
#    restaurant.location.latitude  restaurant.location.longitude  \
# 0                     32.379390                     -86.311010
# 1                     32.355817                     -86.264911
# 2                     32.380500                     -86.314000
# 3                     32.382271                     -86.171836
# 4                     32.380860                     -86.310830
#
#                 coordinate  Arts_Entertainment  College_University  Event  \
# 0    (32.37939, -86.31101)                  12                   3      0
# 1  (32.355817, -86.264911)                   0                   0      0
# 2       (32.3805, -86.314)                  10                   2      0
# 3  (32.382271, -86.171836)                   0                   0      0
# 4    (32.38086, -86.31083)                  11                   2      0
#
#    Nightlife_Spot  Outdoors_Recreation  Professional_n_Other_Places  \
# 0               7                    1                            4
# 1               1                    1                            1
# 2               7                    2                            4
# 3               0                    0                            0
# 4               7                    1                            4
#
#    Shop_Service  Travel_Transport  Residence
# 0             0                 4          1
# 1             2                 0          0
# 2             0                 4          1
# 3             1                 0          0
# 4             0                 4          1

# %%
brimingham_restaurants.head()
# Out:
#                       restaurant.name                  restaurant.cuisines  \
# 0         Bottega Restaurant and Cafe  Italian, Cafe, Pizza, Mediterranean
# 1                         GianMarco's     Italian, Mediterranean, Southern
# 2                          Surin West                   Asian, Sushi, Thai
# 3                           SAW's BBQ                        BBQ, Sandwich
# 4  Joe's Italian Pizza, Pasta & Caffe             Desserts, Italian, Pizza
#
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               40                                      4.9
# 1                               40                                      4.9
# 2                               25                                      4.6
# 3                               25                                      4.7
# 4                               25                                      4.7
#
#                                   restaurant.timings  \
# 0         11 AM to 10 PM (Tue-Sat), Mon & Sun Closed
# 1  5 PM to 10 PM (Mon, Tue, Sat), 11 AM to 2 PM, ...
# 2  11 AM to 9:30 PM (Mon-Thu), 11 AM to 10:30 PM ...
# 3                11 AM to 8 PM (Mon-Sat), Sun Closed
# 4                         10:30 AM to 9 PM (Mon-Sun)
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                            98                         814.0
# 1                           161                         826.0
# 2                           137                         840.0
# 3                           175                         740.0
# 4                           314                         739.0
#
#    restaurant.location.latitude  restaurant.location.longitude  \
# 0                     33.502341                     -86.789783
# 1                     33.463387                     -86.812239
# 2                     33.500760                     -86.795540
# 3                     33.473800                     -86.808290
# 4                     33.259583                     -86.796361
#
#                 coordinate  Arts_Entertainment  College_University  Event  \
# 0  (33.502341, -86.789783)                   2                   1      0
# 1  (33.463387, -86.812239)                   0                   0      0
# 2    (33.50076, -86.79554)                   3                   7      0
# 3     (33.4738, -86.80829)                   0                   0      0
# 4  (33.259583, -86.796361)                   0                   0      0
#
#    Nightlife_Spot  Outdoors_Recreation  Professional_n_Other_Places  \
# 0               7                    3                            2
# 1               0                    1                            0
# 2               7                    3                            2
# 3               1                    0                            0
# 4               0                    0                            0
#
#    Shop_Service  Travel_Transport  Residence
# 0             1                 2          4
# 1             2                 0          1
# 2             1                 2          5
# 3             0                 0          1
# 4             0                 0          0

# %% [markdown]
# After I got the number of for each category venue for each restaurant, for each city. I'll merge the three city restaurant dataframe

# %%
restaurants = pd.concat([tuscaloosa_restaurants, montgomery_restaurants, brimingham_restaurants], axis = 0).reset_index(drop=True)

# %%
restaurants
# Out:
#                                      restaurant.name  \
# 0                                          City Cafe
# 1                            Swen Chinese Restaurant
# 2                             DePalma's Italian Cafe
# 3                                        Cypress Inn
# 4                               Mugshots Grill & Bar
# 5                                Hooligan's American
# 6                           Dreamland BBQ Tuscaloosa
# 7                                       Chuck's Fish
# 8                                           Waysider
# 9                               Nick's in the Sticks
# 10                                          Hokkaido
# 11                            Baumhower's Restaurant
# 12                               Five Bar Tuscaloosa
# 13                                 Surin of Thailand
# 14                                        Rama Jamas
# 15              Kobe Japanese Steakhouse & Sushi Bar
# 16                    Ichiban Japanese Grill & Sushi
# 17                                      Iguana Grill
# 18                                     Newk's Eatery
# 19                    Ruan Thai Restaurant Authentic
# 20                                Lai Lai Restaurant
# 21   Mr Chen's Authentic Cooking and Oriental Market
# 22                  Edelweiss German Bakery and Cafe
# 23                                      Los Tarascos
# 24                               Glory Bound Gyro Co
# 25                                         Taco Casa
# 26                                 Broadway Pizzeria
# 27                         Buffalo Phil's Pub & Cafe
# 28                      Tokyo Japanese Steak & Sushi
# 29                                      Little Italy
# ..                                               ...
# 270                        Crazy Cajuns' Boiling Pot
# 271           Jubilee Joe's Cajun Seafood Restaurant
# 272                                Big Bad Breakfast
# 273                                  Giuseppe's Cafe
# 274                          Sitar Indian Restaurant
# 275                                  Yogurt Mountain
# 276                           Baumhower's Restaurant
# 277                                   Village Tavern
# 278                                  Mellow Mushroom
# 279                                Taste of Thailand
# 280                                            Ginza
# 281                                           Konomi
# 282            Fleming's Prime Steakhouse & Wine Bar
# 283                                   Tortugas Pizza
# 284                   Nori Thai and Sushi Restaurant
# 285                         Salvatores Pizza & Pasta
# 286                                    Satterfield's
# 287                                 De Vinci's Pizza
# 288                        Amore Ristorante Italiano
# 289                       Bellini's Ristorante & Bar
# 290                                   Edgar's Bakery
# 291                    Parish Seafood & Oyster House
# 292                       Costa's Mediterranean Cafe
# 293                      Taziki's Mediterranean Cafe
# 294                                Surin of Thailand
# 295                        Sumo Japanese Steak House
# 296                                       Maki Fresh
# 297                        Nino's Italian Restaurant
# 298                                    Fig Tree Cafe
# 299                           Baumhower's Restaurant
#
#                  restaurant.cuisines  restaurant.average_cost_for_two  \
# 0           Diner, Seafood, Southern                               10
# 1                            Chinese                               25
# 2                            Italian                               40
# 3           American, Seafood, Steak                               40
# 4         American, Burger, Bar Food                               10
# 5            American, Mediterranean                               10
# 6                      BBQ, Desserts                               25
# 7           American, Seafood, Sushi                               40
# 8      American, Breakfast, Southern                               10
# 9                              Steak                               25
# 10                   Japanese, Sushi                               40
# 11           American, Burger, Steak                               25
# 12                    Coffee and Tea                               40
# 13                       Sushi, Thai                               25
# 14                  American, Burger                               10
# 15                   Japanese, Sushi                               40
# 16                   Japanese, Sushi                               10
# 17                  Mexican, Seafood                               25
# 18                American, Sandwich                               10
# 19                  Thai, Vegetarian                               25
# 20                    Asian, Chinese                               10
# 21          Asian, Chinese, Hawaiian                               10
# 22                    Bakery, German                               25
# 23                           Mexican                               10
# 24           American, Mediterranean                               10
# 25                Fast Food, Mexican                               10
# 26                    Italian, Pizza                               10
# 27                  American, Burger                               10
# 28            Japanese, Steak, Sushi                               40
# 29          Italian, Pizza, Sandwich                               10
# ..                               ...                              ...
# 270         American, Seafood, Cajun                               25
# 271                   Seafood, Cajun                               25
# 272  American, Coffee and Tea, Diner                               10
# 273   Italian, Pizza, Sandwich, Cafe                               25
# 274                    Asian, Indian                               25
# 275                         Desserts                               10
# 276       Burger, Bar Food, Sandwich                               25
# 277         Bar Food, Seafood, Steak                               40
# 278    Pizza, Sandwich, Healthy Food                               25
# 279                             Thai                               25
# 280          Japanese, Korean, Sushi                               40
# 281                  Japanese, Sushi                               40
# 282         American, Seafood, Steak                               70
# 283                            Pizza                               25
# 284               Asian, Sushi, Thai                               20
# 285         Italian, Pizza, Sandwich                               25
# 286                American, Seafood                               70
# 287                   Pizza, Italian                               25
# 288  Italian, Mediterranean, Seafood                               70
# 289         Desserts, Italian, Steak                               70
# 290              Breakfast, Sandwich                               10
# 291         Seafood, Southern, Cajun                               40
# 292    Greek, Italian, Mediterranean                               25
# 293   American, Greek, Mediterranean                               25
# 294               Asian, Sushi, Thai                               25
# 295           Japanese, Steak, Sushi                               40
# 296           Asian, Japanese, Sushi                               10
# 297         Italian, Pizza, Sandwich                               10
# 298                             Cafe                               35
# 299       Burger, Bar Food, Sandwich                               25
#
#      restaurant.user_rating.aggregate_rating  \
# 0                                        3.8
# 1                                        3.6
# 2                                        3.8
# 3                                        3.5
# 4                                        3.6
# 5                                        3.6
# 6                                        3.5
# 7                                        3.5
# 8                                        3.6
# 9                                        3.7
# 10                                       3.7
# 11                                       3.5
# 12                                       3.6
# 13                                       3.6
# 14                                       3.6
# 15                                       3.5
# 16                                       3.6
# 17                                       3.4
# 18                                       3.6
# 19                                       3.6
# 20                                       3.4
# 21                                       3.6
# 22                                       3.6
# 23                                       3.5
# 24                                       3.5
# 25                                       3.5
# 26                                       3.5
# 27                                       3.4
# 28                                       3.5
# 29                                       3.5
# ..                                       ...
# 270                                      4.2
# 271                                      3.9
# 272                                      3.9
# 273                                      4.3
# 274                                      4.2
# 275                                      4.1
# 276                                      3.9
# 277                                      4.1
# 278                                      4.2
# 279                                      4.2
# 280                                      4.1
# 281                                      4.3
# 282                                      4.2
# 283                                      4.2
# 284                                      4.2
# 285                                      4.1
# 286                                      4.2
# 287                                      4.1
# 288                                      4.2
# 289                                      3.9
# 290                                      4.0
# 291                                      3.6
# 292                                      3.9
# 293                                      4.2
# 294                                      4.1
# 295                                      3.9
# 296                                      4.0
# 297                                      3.9
# 298                                      4.1
# 299                                      3.9
#
#                                     restaurant.timings  \
# 0               (Sun, Sat), Breakfast, Lunch (Mon-Fri)
# 1    11 AM to 10 PM (Mon, Tue, Wed, Thu, Sun), 11 A...
# 2    Closed (Mon),11 AM to 10 PM (Tue-Thu),11 AM to...
# 3    11 AM to 9 PM (Mon-Thu), 11 AM to 10 PM (Fri-S...
# 4    11 AM to 10 PM (Mon-Thu),11 AM to 11 PM (Fri-S...
# 5    Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)
# 6         10 AM to 9 PM (Mon-Sat), 11 AM to 9 PM (Sun)
# 7    5 PM to 10 PM (Mon-Thu),5 PM to 11 PM (Fri-Sat...
# 8    Closed (Mon),5:30 AM to 2 PM (Tue-Fri),5:30 AM...
# 9    5 PM to 9 PM (Mon-Thu),5 PM to 10 PM (Fri-Sat)...
# 10   11 AM to 2:30 PM, 4:30 PM to 10 PM (Mon-Thu, S...
# 11     9:50 AM a 10:10 AM (Seg),10 AM a 8 PM (Ter-Dom)
# 12   5 PM to 10 PM (Mon-Thu),11 AM to 12 Midnight (...
# 13   11 AM to 2 PM, 4:30 PM to 9:30 PM (Mon-Thu),11...
# 14                    (Sun),Breakfast, Lunch (Mon-Sat)
# 15   11 AM to 2 PM, 4:30 PM to 10 PM (Mon-Thu),11 A...
# 16   Lunch, Dinner (Sun, Tue, Wed, Fri, Sat),  (Mon...
# 17
# 18                11 AM to 10 PM (Mon-Sat), Sun Closed
# 19          (Sun),Lunch, Dinner (Mon-Fri),Dinner (Sat)
# 20               11 AM to 2 PM, 5 PM to 9 PM (Mon-Sun)
# 21   Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)
# 22        6:30 AM to 5 PM (Mon-Sat),8 AM to 2 PM (Sun)
# 23   Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)
# 24   11 AM to 10 PM (Mon-Thu),11 AM to 11 PM (Fri-S...
# 25   10:30 AM to 11 PM (Mon, Tue, Wed, Thu, Sun), 1...
# 26   11 AM to 9:30 PM (Mon-Thu, Sun), 11 AM to 10:3...
# 27   11 AM to 11 PM (Mon, Tue, Wed, Sat), 11 AM to ...
# 28   4:30 PM to 10 PM (Mon-Thu),4:30 PM to 11 PM (F...
# 29   Lunch, Dinner (Sun),Lunch, Dinner, Late (Mon-Sat)
# ..                                                 ...
# 270  11 AM to 9 PM (Mon-Thu),11 AM to 10 PM (Fri-Sa...
# 271  Closed (Mon),11 AM to 9 PM (Tue-Thu),11 AM to ...
# 272                          7 AM to 2:30 PM (Mon-Sun)
# 273  11 AM to 9:30 PM (Mon),11 AM to 10 PM (Tue-Sat...
# 274        11 AM to 2:30 PM, 5 PM to 9:30 PM (Mon-Sun)
# 275  11:30 AM to 11 PM (Mon, Tue, Wed, Thu, Sun), 1...
# 276  11 AM to 10 PM (Mon, Tue, Wed, Thu, Sun), 11 A...
# 277  11 AM to 10 PM (Mon-Thu), 11 AM to 11 PM (Fri-...
# 278  11 AM to 10 PM (Mon-Thu, Sun), 11 AM to 11 PM ...
# 279  11 AM to 1:30 PM, 4:30 PM to 8:30 PM (Tue-Fri)...
# 280  11 AM to 2 PM, 5 PM to 10 PM (Tue-Fri), 11 AM ...
# 281  11 AM to 2 PM, 4:30 PM to 9:30 PM (Mon-Thu),11...
# 282  4:30 PM to 10 PM (Mon-Thu), 4:30 PM to 11 PM (...
# 283  Closed (Mon, Sun), 4 PM to 8:30 PM (Tue-Thu),1...
# 284  11 AM to 9 PM (Tue-Thu, Sun), 11 AM to 10 PM (...
# 285                                     11 AM to 10 PM
# 286  4 PM to 9 PM (Mon-Thu),4 PM to 10 PM (Fri-Sat)...
# 287  11 AM to 9 PM (Mon, Tue, Wed, Sun), 7 AM to 9 ...
# 288  Closed (Mon, Sun), 5 PM to 9 PM (Tue-Thu),5 PM...
# 289  11 AM to 2 PM, 4 PM to 9 PM (Mon-Wed), 11 AM t...
# 290             6:30 AM to 6 PM (Mon-Sat),Closed (Sun)
# 291     11 AM to 10 PM (Mon-Sat),12 Noon to 3 PM (Sun)
# 292  11 AM to 9 PM (Mon-Thu),11 AM to 10 PM (Fri),1...
# 293       11 AM to 9 PM (Mon-Sat), 11 AM to 8 PM (Sun)
# 294  11:15 AM to 2 PM, 5 PM to 9 PM (Mon, Tue, Wed,...
# 295  11 AM to 2 PM, 4 PM to 10 PM (Mon-Thu),11 AM t...
# 296                            11 AM to 9 PM (Mon-Sun)
# 297  11 AM to 9 PM (Mon-Wed),11 AM to 11 PM (Thu-Sa...
# 298  Closed (Mon),11 AM to 2 PM, 5 PM to 9 PM (Tue-...
# 299  11 AM to 10 PM (Mon, Tue, Wed, Thu, Sun), 11 A...
#
#      restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                              38                         288.0
# 1                              37                         192.0
# 2                              93                         428.0
# 3                              60                         303.0
# 4                              74                         295.0
# 5                              39                         246.0
# 6                              62                         266.0
# 7                              47                         242.0
# 8                              39                         236.0
# 9                              38                         207.0
# 10                             43                         234.0
# 11                            106                         214.0
# 12                             50                         200.0
# 13                             43                         201.0
# 14                             38                         188.0
# 15                             38                         145.0
# 16                             27                         138.0
# 17                             35                         140.0
# 18                             22                         140.0
# 19                             32                         127.0
# 20                             29                          85.0
# 21                             27                         127.0
# 22                             20                         120.0
# 23                             28                         106.0
# 24                             31                         114.0
# 25                             22                         121.0
# 26                             34                         106.0
# 27                             26                         113.0
# 28                             24                          98.0
# 29                             23                         106.0
# ..                            ...                           ...
# 270                            82                         233.0
# 271                            78                         196.0
# 272                            86                         212.0
# 273                            49                         240.0
# 274                            60                         232.0
# 275                            44                         246.0
# 276                           101                         219.0
# 277                            41                         231.0
# 278                            41                         239.0
# 279                            58                         216.0
# 280                            60                         215.0
# 281                            50                         211.0
# 282                            43                         226.0
# 283                            44                         228.0
# 284                            88                         175.0
# 285                            52                         219.0
# 286                            42                         197.0
# 287                            66                         205.0
# 288                            82                         174.0
# 289                            60                         186.0
# 290                            60                         193.0
# 291                            93                         149.0
# 292                            54                         185.0
# 293                            24                         209.0
# 294                            25                         212.0
# 295                            48                         190.0
# 296                            39                         183.0
# 297                           105                         186.0
# 298                            97                         137.0
# 299                            91                         181.0
#
#      restaurant.location.latitude  restaurant.location.longitude  \
# 0                       33.218100                     -87.578300
# 1                       33.210820                     -87.552750
# 2                       33.210400                     -87.567100
# 3                       33.229210                     -87.528630
# 4                       33.209600                     -87.568100
# 5                       33.211500                     -87.561800
# 6                       33.157370                     -87.516760
# 7                       33.209613                     -87.568381
# 8                       33.199600                     -87.564300
# 9                       33.177203                     -87.614321
# 10                      33.196857                     -87.528237
# 11                      33.212937                     -87.523579
# 12                      33.209271                     -87.566952
# 13                      33.211304                     -87.555330
# 14                      33.206500                     -87.551700
# 15                      33.194413                     -87.526284
# 16                      33.198892                     -87.541599
# 17                      33.235573                     -87.549777
# 18                      33.206873                     -87.533615
# 19                      33.211200                     -87.555900
# 20                      33.229768                     -87.533065
# 21                      33.200046                     -87.543563
# 22                      33.211245                     -87.567738
# 23                      33.168400                     -87.514600
# 24                      33.209680                     -87.568116
# 25                      33.237149                     -87.566315
# 26                      33.242280                     -87.512150
# 27                      33.210600                     -87.552900
# 28                      33.153600                     -87.547700
# 29                      33.210867                     -87.552707
# ..                            ...                            ...
# 270                     33.420057                     -86.696421
# 271                     33.351555                     -86.864997
# 272                     33.418968                     -86.671473
# 273                     33.495194                     -86.814348
# 274                     33.505745                     -86.799586
# 275                     33.461276                     -86.753785
# 276                     33.373709                     -86.815875
# 277                     33.449380                     -86.732290
# 278                     33.499520                     -86.795810
# 279                     33.393833                     -86.798166
# 280                     33.414246                     -86.699845
# 281                     33.644580                     -86.636770
# 282                     33.449380                     -86.732290
# 283                     33.365363                     -86.823826
# 284                     33.433180                     -86.737950
# 285                     33.401560                     -86.806140
# 286                     33.454323                     -86.733631
# 287                     33.482389                     -86.791635
# 288                     33.405996                     -86.664275
# 289                     33.412140                     -86.675780
# 290                     33.374327                     -86.814908
# 291                     33.608552                     -86.628200
# 292                     33.390984                     -86.796867
# 293                     33.437269                     -86.729698
# 294                     33.502230                     -86.755730
# 295                     33.375051                     -86.814665
# 296                     33.463440                     -86.746140
# 297                     33.315206                     -86.800347
# 298                     33.454987                     -86.733677
# 299                     33.410897                     -86.671196
#
#                     coordinate  Arts_Entertainment  College_University  Event  \
# 0          (33.2181, -87.5783)                   4                   0      1
# 1        (33.21082, -87.55275)                   6                  23      1
# 2          (33.2104, -87.5671)                  11                   0      2
# 3        (33.22921, -87.52863)                   0                   0      0
# 4          (33.2096, -87.5681)                  11                   0      2
# 5          (33.2115, -87.5618)                   9                   0      2
# 6        (33.15737, -87.51676)                   0                   0      0
# 7      (33.209613, -87.568381)                  11                   0      2
# 8          (33.1996, -87.5643)                   3                   0      1
# 9      (33.177203, -87.614321)                   0                   0      0
# 10   (33.1968566, -87.5282368)                   0                   1      0
# 11     (33.212937, -87.523579)                   0                   2      0
# 12     (33.209271, -87.566952)                  11                   0      2
# 13      (33.211304, -87.55533)                   7                  16      1
# 14         (33.2065, -87.5517)                   5                  24      1
# 15     (33.194413, -87.526284)                   1                   1      0
# 16     (33.198892, -87.541599)                   2                   1      0
# 17   (33.2355725, -87.5497772)                   1                   0      0
# 18     (33.206873, -87.533615)                   2                   3      0
# 19         (33.2112, -87.5559)                   8                  15      1
# 20    (33.229768, -87.5330649)                   1                   0      0
# 21   (33.2000455, -87.5435632)                   2                   4      0
# 22     (33.211245, -87.567738)                  10                   0      2
# 23         (33.1684, -87.5146)                   0                   0      0
# 24      (33.20968, -87.568116)                  11                   0      2
# 25     (33.237149, -87.566315)                   0                   0      0
# 26       (33.24228, -87.51215)                   0                   0      0
# 27         (33.2106, -87.5529)                   6                  23      1
# 28         (33.1536, -87.5477)                   0                   0      0
# 29     (33.210867, -87.552707)                   6                  23      1
# ..                         ...                 ...                 ...    ...
# 270    (33.420057, -86.696421)                   0                   0      0
# 271    (33.351555, -86.864997)                   0                   0      0
# 272   (33.4189679, -86.671473)                   0                   0      0
# 273    (33.495194, -86.814348)                   1                  17      0
# 274    (33.505745, -86.799586)                   4                  13      0
# 275    (33.461276, -86.753785)                   0                   0      0
# 276    (33.373709, -86.815875)                   1                   0      0
# 277      (33.44938, -86.73229)                   0                   0      1
# 278      (33.49952, -86.79581)                   2                   8      0
# 279    (33.393833, -86.798166)                   0                   0      0
# 280    (33.414246, -86.699845)                   0                   0      0
# 281      (33.64458, -86.63677)                   0                   0      0
# 282      (33.44938, -86.73229)                   0                   0      1
# 283    (33.365363, -86.823826)                   0                   0      0
# 284      (33.43318, -86.73795)                   0                   0      0
# 285      (33.40156, -86.80614)                   0                   0      0
# 286    (33.454323, -86.733631)                   0                   0      1
# 287    (33.482389, -86.791635)                   0                   0      0
# 288    (33.405996, -86.664275)                   0                   0      1
# 289      (33.41214, -86.67578)                   0                   0      0
# 290    (33.374327, -86.814908)                   1                   0      1
# 291   (33.608552, -86.6282001)                   0                   0      0
# 292    (33.390984, -86.796867)                   0                   0      0
# 293   (33.437269, -86.7296985)                   0                   0      0
# 294      (33.50223, -86.75573)                   0                   0      0
# 295    (33.375051, -86.814665)                   1                   0      1
# 296      (33.46344, -86.74614)                   0                   0      0
# 297    (33.315206, -86.800347)                   0                   0      0
# 298    (33.454987, -86.733677)                   0                   0      1
# 299    (33.410897, -86.671196)                   0                   0      1
#
#      Nightlife_Spot  Outdoors_Recreation  Professional_n_Other_Places  \
# 0                 1                    0                            1
# 1                 9                    4                            4
# 2                17                    3                            6
# 3                 0                    0                            2
# 4                17                    3                            6
# 5                24                    3                            5
# 6                 0                    0                            0
# 7                17                    3                            6
# 8                 2                    2                            3
# 9                 0                    0                            0
# 10                1                    3                            3
# 11                1                    2                            2
# 12               17                    3                            6
# 13               11                    4                            3
# 14                8                    3                            3
# 15                1                    3                            2
# 16                1                    1                            3
# 17                0                    4                            1
# 18                1                    4                            2
# 19               13                    4                            3
# 20                0                    1                            2
# 21                1                    1                            3
# 22               17                    3                            6
# 23                0                    0                            2
# 24               17                    3                            6
# 25                0                    3                            0
# 26                0                    0                            1
# 27                9                    4                            4
# 28                0                    0                            0
# 29                9                    4                            4
# ..              ...                  ...                          ...
# 270               0                    0                            0
# 271               0                    0                            0
# 272               0                    0                            0
# 273               0                    0                            0
# 274               8                    4                            3
# 275               0                    0                            0
# 276               0                    0                            1
# 277               0                    0                            0
# 278               6                    4                            1
# 279               0                    0                            0
# 280               0                    0                            0
# 281               0                    0                            0
# 282               0                    0                            0
# 283               0                    0                            0
# 284               0                    1                            1
# 285               0                    0                            1
# 286               0                    0                            0
# 287               0                    3                            1
# 288               0                    0                            1
# 289               0                    0                            0
# 290               0                    0                            1
# 291               0                    0                            0
# 292               0                    0                            0
# 293               0                    1                            1
# 294               0                    0                            0
# 295               0                    0                            1
# 296               0                    0                            0
# 297               0                    0                            0
# 298               0                    0                            0
# 299               0                    0                            1
#
#      Shop_Service  Travel_Transport  Residence
# 0               0                 2          0
# 1               4                 0          1
# 2               2                 7          1
# 3               0                 0          1
# 4               2                 7          1
# 5               4                 7          1
# 6               0                 0          0
# 7               2                 7          1
# 8               0                 1          1
# 9               0                 0          0
# 10             16                 0          4
# 11              0                 1          5
# 12              2                 6          1
# 13              3                 2          1
# 14              4                 0          3
# 15             16                 1          2
# 16              1                 1          4
# 17              0                 1          1
# 18              2                 1          3
# 19              3                 2          1
# 20              0                 1          0
# 21              1                 1          4
# 22              2                 7          1
# 23              0                 2          1
# 24              2                 7          1
# 25              0                 1          1
# 26              0                 0          0
# 27              4                 0          1
# 28              0                 0          1
# 29              4                 0          1
# ..            ...               ...        ...
# 270             0                 1          0
# 271             0                 0          0
# 272             0                 0          0
# 273             0                 0          1
# 274             2                 5          3
# 275             1                 0          0
# 276             0                 0          0
# 277             4                 0          0
# 278             1                 2          4
# 279             0                 0          0
# 280             0                 1          0
# 281             0                 0          0
# 282             4                 0          0
# 283             0                 1          1
# 284             0                 0          0
# 285             0                 0          0
# 286             4                 0          0
# 287             3                 1          4
# 288             0                 0          0
# 289             0                 0          0
# 290             0                 1          0
# 291             0                 0          0
# 292             0                 0          0
# 293             0                 3          1
# 294             0                 0          0
# 295             0                 1          0
# 296             1                 0          0
# 297             0                 0          0
# 298             3                 0          0
# 299             0                 0          0
#
# [300 rows x 19 columns]

# %%
restaurants.to_csv("restaurants.csv")

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# ### 3.1 Explore Dataset

# %% [markdown]
# ### Visualize the Restaurants  venue

# %%
loc = [33.5186, -86.8104]
map_ = folium.Map(loc, zoom_start = 11)

for lat, lon, poi in zip(restaurants['restaurant.location.latitude'], restaurants['restaurant.location.longitude'], restaurants['restaurant.name']):
    label = folium.Popup(poi, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color= 'blue',
        fill_opacity=0.7).add_to(map_)

map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.2 Pre-processing Data

# %%
X = restaurants.drop(['restaurant.name', 'restaurant.cuisines', 'restaurant.timings', 'coordinate','restaurant.location.latitude','restaurant.location.longitude'],axis = 1)
X.head()
# Out:
#    restaurant.average_cost_for_two  restaurant.user_rating.aggregate_rating  \
# 0                               10                                      3.8
# 1                               25                                      3.6
# 2                               40                                      3.8
# 3                               40                                      3.5
# 4                               10                                      3.6
#
#    restaurant.all_reviews_count  restaurant.user_rating.votes  \
# 0                            38                         288.0
# 1                            37                         192.0
# 2                            93                         428.0
# 3                            60                         303.0
# 4                            74                         295.0
#
#    Arts_Entertainment  College_University  Event  Nightlife_Spot  \
# 0                   4                   0      1               1
# 1                   6                  23      1               9
# 2                  11                   0      2              17
# 3                   0                   0      0               0
# 4                  11                   0      2              17
#
#    Outdoors_Recreation  Professional_n_Other_Places  Shop_Service  \
# 0                    0                            1             0
# 1                    4                            4             4
# 2                    3                            6             2
# 3                    0                            2             0
# 4                    3                            6             2
#
#    Travel_Transport  Residence
# 0                 2          0
# 1                 0          1
# 2                 7          1
# 3                 0          1
# 4                 7          1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
X = scaler.transform(X)
X
# Out:
# array([[-0.87596737, -0.23189218, -0.1432726 , ..., -0.54664725,
#          0.29243116, -0.73186535],
#        [ 0.13606168, -0.71500088, -0.16758356, ...,  0.6525789 ,
#         -0.66635953, -0.01199779],
#        [ 1.14809073, -0.23189218,  1.19383029, ...,  0.05296582,
#          2.68940789, -0.01199779],
#        ...,
#        [-0.87596737,  0.00966217,  1.48556182, ..., -0.54664725,
#         -0.66635953, -0.73186535],
#        [ 0.81074772,  0.49277087,  1.29107413, ...,  0.35277236,
#         -0.66635953, -0.73186535],
#        [ 0.13606168,  0.00966217,  1.14520836, ..., -0.54664725,
#         -0.66635953, -0.73186535]])

# %% [markdown]
# ### 3.3 Clustering

# %% [markdown]
# I'm going to cluster the restaurants using K-Means Clustering

# %% [markdown]
# #### Find the optimum number of cluster

# %% [markdown]
# Write a loop that calculates and saves the WCSS for any number of clusters from 1 up to 10 (or more if you wish).

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans= KMeans(i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [3900.0,
#  2836.110773754155,
#  2361.044930344215,
#  2047.0038774927964,
#  1774.2128498381935,
#  1579.4911747315568,
#  1391.3167756583084,
#  1274.3282279880764,
#  1175.8833981844757,
#  1096.360248664638]

# %% [markdown]
# #### Using Kneed in selecting the Elbow Point

# %%
import sys
sys.path.append('..')

from kneed import KneeLocator

K = range(1,11)
kn = KneeLocator(list(K), wcss, S = 1.0, curve = 'convex', direction = 'decreasing')
kn.knee
# Out:
# 4

# %% [markdown]
# From the result, the optimum number of clusters is 4, so i'm going to cluster the restaurants in to 4 cluster

# %%
clusterNumber = 4
k_means = KMeans(init = "k-means++", n_clusters = clusterNumber, n_init = 12, random_state=3425)
k_means.fit(X)
class_label = k_means.labels_
restaurants['class'] = class_label

# %% [markdown]
# ## 4. Results

# %% [markdown]
# ### 4.1 Visualize Clusters

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(loc, zoom_start = 10)

# set color scheme for the clusters
x = np.arange(clusterNumber)
ys = [i + x + (i*x)**2 for i in range(clusterNumber)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
labels = restaurants['restaurant.name']

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(restaurants['restaurant.location.latitude'], restaurants['restaurant.location.longitude'], labels, restaurants['class']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 4.2 Explore each Clusters

# %%
restaurants[restaurants['class'] == 0].describe()
# Out:
#        restaurant.average_cost_for_two  \
# count                        30.000000
# mean                         17.166667
# std                          10.144077
# min                          10.000000
# 25%                          10.000000
# 50%                          10.000000
# 75%                          25.000000
# max                          40.000000
#
#        restaurant.user_rating.aggregate_rating  restaurant.all_reviews_count  \
# count                                30.000000                     30.000000
# mean                                  3.623333                     26.333333
# std                                   0.355919                     21.497928
# min                                   3.200000                      2.000000
# 25%                                   3.400000                      7.250000
# 50%                                   3.500000                     22.500000
# 75%                                   3.600000                     40.250000
# max                                   4.500000                     72.000000
#
#        restaurant.user_rating.votes  restaurant.location.latitude  \
# count                     30.000000                     30.000000
# mean                     143.266667                     33.259968
# std                      115.043600                      0.122429
# min                       31.000000                     33.188300
# 25%                       57.250000                     33.194268
# 50%                       96.500000                     33.202094
# 75%                      198.750000                     33.211278
# max                      479.000000                     33.505745
#
#        restaurant.location.longitude  Arts_Entertainment  College_University  \
# count                      30.000000           30.000000           30.000000
# mean                      -87.389030            2.466667            9.133333
# std                         0.300141            2.687562            9.416542
# min                       -87.555900            0.000000            0.000000
# 25%                       -87.547568            0.000000            1.000000
# 50%                       -87.527396            1.000000            2.000000
# 75%                       -87.525817            5.000000           16.000000
# max                       -86.795810            8.000000           24.000000
#
#            Event  Nightlife_Spot  Outdoors_Recreation  \
# count  30.000000       30.000000            30.000000
# mean    0.266667        4.466667             3.100000
# std     0.449776        3.971739             0.758856
# min     0.000000        1.000000             2.000000
# 25%     0.000000        1.000000             3.000000
# 50%     0.000000        2.000000             3.000000
# 75%     0.750000        8.000000             4.000000
# max     1.000000       13.000000             4.000000
#
#        Professional_n_Other_Places  Shop_Service  Travel_Transport  Residence  \
# count                    30.000000     30.000000         30.000000  30.000000
# mean                      2.366667      8.766667          0.900000   2.333333
# std                       1.098065      6.579400          1.295882   1.184187
# min                       0.000000      0.000000          0.000000   1.000000
# 25%                       1.250000      3.000000          0.000000   1.000000
# 50%                       3.000000      7.000000          0.000000   2.500000
# 75%                       3.000000     16.000000          1.000000   3.000000
# max                       4.000000     17.000000          5.000000   4.000000
#
#        class
# count   30.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0

# %%
restaurants[restaurants['class'] == 1].describe()
# Out:
#        restaurant.average_cost_for_two  \
# count                        90.000000
# mean                         32.500000
# std                          16.663389
# min                          10.000000
# 25%                          25.000000
# 50%                          25.000000
# 75%                          40.000000
# max                          70.000000
#
#        restaurant.user_rating.aggregate_rating  restaurant.all_reviews_count  \
# count                                90.000000                     90.000000
# mean                                  4.264444                     86.188889
# std                                   0.281773                     45.392395
# min                                   3.500000                     17.000000
# 25%                                   4.100000                     60.000000
# 50%                                   4.300000                     78.000000
# 75%                                   4.400000                    104.000000
# max                                   4.900000                    314.000000
#
#        restaurant.user_rating.votes  restaurant.location.latitude  \
# count                     90.000000                     90.000000
# mean                     352.522222                     33.314249
# std                      183.944375                      0.363828
# min                       72.000000                     32.319198
# 25%                      214.250000                     33.376009
# 50%                      293.000000                     33.449320
# 75%                      457.250000                     33.483723
# max                      840.000000                     33.644580
#
#        restaurant.location.longitude  Arts_Entertainment  College_University  \
# count                      90.000000            90.00000           90.000000
# mean                      -86.723974             0.70000            0.744444
# std                         0.219879             1.18464            2.594554
# min                       -87.528630             0.00000            0.000000
# 25%                       -86.798308             0.00000            0.000000
# 50%                       -86.781281             0.00000            0.000000
# 75%                       -86.727102             1.00000            0.000000
# max                       -86.171836             5.00000           17.000000
#
#            Event  Nightlife_Spot  Outdoors_Recreation  \
# count  90.000000       90.000000            90.000000
# mean    0.233333        1.200000             0.777778
# std     0.425322        2.445817             1.139463
# min     0.000000        0.000000             0.000000
# 25%     0.000000        0.000000             0.000000
# 50%     0.000000        0.000000             0.000000
# 75%     0.000000        1.000000             1.000000
# max     1.000000       12.000000             4.000000
#
#        Professional_n_Other_Places  Shop_Service  Travel_Transport  Residence  \
# count                    90.000000     90.000000         90.000000  90.000000
# mean                      0.566667      1.188889          0.533333   1.011111
# std                       0.750281      1.542612          0.876664   1.597009
# min                       0.000000      0.000000          0.000000   0.000000
# 25%                       0.000000      0.000000          0.000000   0.000000
# 50%                       0.000000      0.000000          0.000000   0.000000
# 75%                       1.000000      2.000000          1.000000   1.000000
# max                       3.000000      5.000000          5.000000   5.000000
#
#        class
# count   90.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0

# %%
restaurants[restaurants['class'] == 2].describe()
# Out:
#        restaurant.average_cost_for_two  \
# count                       144.000000
# mean                         17.361111
# std                           9.822631
# min                           0.000000
# 25%                          10.000000
# 50%                          10.000000
# 75%                          25.000000
# max                          40.000000
#
#        restaurant.user_rating.aggregate_rating  restaurant.all_reviews_count  \
# count                               144.000000                    144.000000
# mean                                  3.751389                     20.833333
# std                                   0.332817                     12.884641
# min                                   2.900000                      2.000000
# 25%                                   3.400000                     12.000000
# 50%                                   3.800000                     18.000000
# 75%                                   4.000000                     27.000000
# max                                   4.600000                     86.000000
#
#        restaurant.user_rating.votes  restaurant.location.latitude  \
# count                    144.000000                    144.000000
# mean                      79.506944                     32.775915
# std                       56.145913                      0.439794
# min                       17.000000                     32.265915
# 25%                       41.000000                     32.360474
# 50%                       57.000000                     32.461224
# 75%                       98.500000                     33.228584
# max                      288.000000                     33.503198
#
#        restaurant.location.longitude  Arts_Entertainment  College_University  \
# count                     144.000000          144.000000          144.000000
# mean                      -86.777899            0.791667            0.423611
# std                         0.613246            1.625303            1.397199
# min                       -87.614321            0.000000            0.000000
# 25%                       -87.534937            0.000000            0.000000
# 50%                       -86.417057            0.000000            0.000000
# 75%                       -86.216523            1.000000            0.000000
# max                       -86.125364           11.000000            8.000000
#
#             Event  Nightlife_Spot  Outdoors_Recreation  \
# count  144.000000      144.000000           144.000000
# mean     0.062500        0.673611             0.520833
# std      0.242906        1.151647             0.868797
# min      0.000000        0.000000             0.000000
# 25%      0.000000        0.000000             0.000000
# 50%      0.000000        0.000000             0.000000
# 75%      0.000000        1.000000             1.000000
# max      1.000000        6.000000             5.000000
#
#        Professional_n_Other_Places  Shop_Service  Travel_Transport  \
# count                   144.000000    144.000000        144.000000
# mean                      0.902778      0.861111          0.854167
# std                       1.302603      1.186233          1.170552
# min                       0.000000      0.000000          0.000000
# 25%                       0.000000      0.000000          0.000000
# 50%                       0.000000      0.000000          0.000000
# 75%                       1.000000      1.000000          1.000000
# max                       6.000000      5.000000          6.000000
#
#         Residence  class
# count  144.000000  144.0
# mean     0.659722    2.0
# std      1.183589    0.0
# min      0.000000    2.0
# 25%      0.000000    2.0
# 50%      0.000000    2.0
# 75%      1.000000    2.0
# max      4.000000    2.0

# %%
restaurants[restaurants['class'] == 3].describe()
# Out:
#        restaurant.average_cost_for_two  \
# count                        36.000000
# mean                         26.527778
# std                          17.105531
# min                          10.000000
# 25%                          10.000000
# 50%                          25.000000
# 75%                          40.000000
# max                          70.000000
#
#        restaurant.user_rating.aggregate_rating  restaurant.all_reviews_count  \
# count                                36.000000                     36.000000
# mean                                  3.780556                     45.027778
# std                                   0.443892                     33.889304
# min                                   3.300000                      9.000000
# 25%                                   3.400000                     18.500000
# 50%                                   3.600000                     35.000000
# 75%                                   4.200000                     59.500000
# max                                   4.700000                    151.000000
#
#        restaurant.user_rating.votes  restaurant.location.latitude  \
# count                     36.000000                     36.000000
# mean                     166.194444                     33.030878
# std                      137.039477                      0.425089
# min                       15.000000                     32.373300
# 25%                       56.750000                     32.381107
# 50%                      117.000000                     33.210501
# 75%                      237.500000                     33.211870
# max                      595.000000                     33.522703
#
#        restaurant.location.longitude  Arts_Entertainment  College_University  \
# count                      36.000000           36.000000           36.000000
# mean                      -87.090720           11.472222            0.972222
# std                         0.564168            2.104229            1.253250
# min                       -87.573860            9.000000            0.000000
# 25%                       -87.567325           10.000000            0.000000
# 50%                       -87.563131           11.000000            0.000000
# 75%                       -86.313253           12.250000            2.000000
# max                       -86.303200           16.000000            3.000000
#
#            Event  Nightlife_Spot  Outdoors_Recreation  \
# count  36.000000       36.000000            36.000000
# mean    1.111111       13.722222             2.750000
# std     0.949520        5.485623             1.518928
# min     0.000000        3.000000             1.000000
# 25%     0.000000        7.000000             1.000000
# 50%     1.500000       16.000000             3.000000
# 75%     2.000000       17.000000             3.000000
# max     2.000000       24.000000             6.000000
#
#        Professional_n_Other_Places  Shop_Service  Travel_Transport  Residence  \
# count                    36.000000     36.000000         36.000000  36.000000
# mean                      5.611111      1.472222          6.083333   1.361111
# std                       1.225393      1.182881          1.556094   1.018480
# min                       3.000000      0.000000          2.000000   0.000000
# 25%                       5.000000      0.000000          4.000000   1.000000
# 50%                       6.000000      2.000000          7.000000   1.000000
# 75%                       6.000000      2.000000          7.000000   1.000000
# max                       8.000000      4.000000          8.000000   4.000000
#
#        class
# count   36.0
# mean     3.0
# std      0.0
# min      3.0
# 25%      3.0
# 50%      3.0
# 75%      3.0
# max      3.0

# %% [markdown]
# By looking at the stats descrption, in the cluster 1 the restaurants seems more expensive than the other clusters, and the number of rating votes is higher than the other clusters and also the rating is really high.

# %% [markdown]
# But if we looking for the good location strategy for restaurant to invest, we can consider cluster 0,just by looking at the stat desc, we can see that cluster 0 have more variety of venues around their restaurants.

# %%
cluster_0 = restaurants[restaurants['class'] == 0]
cluster_1 = restaurants[restaurants['class'] == 1]
cluster_2 = restaurants[restaurants['class'] == 2]
cluster_3 = restaurants[restaurants['class'] == 3]
clusters = [cluster_0,cluster_1,cluster_2,cluster_3]

# %% [markdown]
# We can use Heatmap to visualize the number of venue for each category for each restuarants in every cluster

# %%
plt.figure(figsize= (10,15))
sns.heatmap(clusters[0].loc[:,'Arts_Entertainment':"Residence"],cmap = 'Blues')

# %%
plt.figure(figsize= (10,35))
sns.heatmap(clusters[1].loc[:,'Arts_Entertainment':'Residence'],cmap = 'Blues')

# %%
plt.figure(figsize= (10,40))
sns.heatmap(clusters[2].loc[:,'Arts_Entertainment':"Residence"],cmap = 'Blues')

# %%
plt.figure(figsize= (10,10))
sns.heatmap(clusters[3].loc[:,'Arts_Entertainment':"Residence"],cmap = 'Blues')

# %% [markdown]
# ### 4.3 Answer the question

# %% [markdown]
# From the Heatmaps we can see that, in cluster 0, cluster 3 their restaurants have more venues around them than the other clusters, and it seems the cluster 3 is a better choice if we want to invest our money in to one of the restaurants, based on the location strategy.

# %% [markdown]
# Visualize all the restaurants and the venues

# %% [markdown]
# First, i'm going to concat every city venues datas in two one dataframe, and then i'm going to plot every venue using their coordinate, and beside that i'm also going to plot all the restaurants with their clusters

# %%
def venues_dataframe(dataframes):
    venues = pd.DataFrame()
    for i in dataframes.keys():
        venues = pd.concat([dataframes[i], venues], axis = 0)
    venues.reset_index(inplace=True, drop=True)
    return venues
d1 = venues_dataframe(Tuscaloosa_venues)
d2 = venues_dataframe(Montgomery_venues)
d3 = venues_dataframe(Brimingham_venues)
venues = pd.concat([d1,d2,d3], axis = 0).reset_index(drop=True)

# %%
venues.head()
# Out:
#                                  categories                        id  \
# 0  Residential Building (Apartment / Condo)  4c66de7919f3c9b6ff20a1ff
# 1  Residential Building (Apartment / Condo)  4c0c04e57e3fc9282731f682
# 2  Residential Building (Apartment / Condo)  4c5b243904f9be9ab78df360
# 3  Residential Building (Apartment / Condo)  56468afd498ea0ff87ff9e60
# 4  Residential Building (Apartment / Condo)  4e0e3171d4c0f6d6b3f7b912
#
#                            location.formattedAddress  location.lat  \
# 0  1100 Hargrove Rd E, Tuscaloosa, AL 35405, Unit...     33.189918
# 1  grace street (University blvd.), Tuscaloosa, A...     33.212656
# 2  1900 Rice Mine Rd N, Tuscaloosa, AL 35406, Uni...     33.222982
# 3  1418 10th Ave, Tuscaloosa, AL 35401, United St...     33.200005
# 4  1100 17th St (17th St), Tuscaloosa, AL 35401, ...     33.197602
#
#    location.lng                    name  \
# 0    -87.521484     Redpoint Tuscaloosa
# 1    -87.554469         Preston place 2
# 2    -87.562209   High River Apartments
# 3    -87.551736          Ion Tuscaloosa
# 4    -87.552679  Crimson Student Living
#
#                                 coordinate
# 0  (33.18991839517019, -87.52148384698012)
# 1  (33.21265578497721, -87.55446886038843)
# 2  (33.22298177790168, -87.56220913207223)
# 3  (33.20000484521273, -87.55173637349237)
# 4   (33.19760245537503, -87.5526792509311)

# %%
venues.to_csv("venues.csv")

# %%
venu_labels = venues['categories'] + ', ' + venues['name'].astype(str)
for lat, lon, poi in zip(venues['location.lat'], venues['location.lng'], venu_labels):
    label = folium.Popup(poi, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='grey',
        fill=True,
        fill_color= 'grey',
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# For this project, k-means works properly. we use the most common venues in neighborhood, cluster the neighborhoods into 6 clusters. The result is good for our problem.
#
# Although the result is accurate, we can also notice that the clusters is not precise enough. Adding more features like population and average income would be helpful.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# 1. Cluster 0 : just by looking at the stat desc and the heatmap, we can see that cluster 0 have more variety of venues around their restaurants and the number of the venues is high, their price is cheaper than in other clusters, and the number of user voting is high,. If we want to invest our money in restaurants that have their customer are mostly college students, then we can consider this cluster as a good place to invest.
# 2. Cluster 1 : in cluster 1, the restaurants have higher rating with average over 4 than other clusters, have more reviews and the user voting is also higher than any other clusters, and the price for two is more expencive than the other restaurants in other cluster, but unfortunately the location strategy is not good because the number of venue around their restaurant is smaller then the other clusters. If we want to consider to invest our money to restaurants that have many customer, high rating, more expensive cost, than this place is a good place to invest.
# 3. Cluster 2 : in cluster 2, the price for two cheaper then the other clusters with average rating 3. Based on the heatmap, cluster 2 have variety of venues around their restaurants. But for the loaction strategy, this cluster is better than cluster 1.
# 4. Cluster  3: From the Heatmaps, in cluster 3, their restaurants have more variety venues around them, and the number of each venue is higher than any other clusters, espcecially their Arts and Entertainment venue. By looking at the stat description, their price for two is consider expensive but their number of customer voting is higher than any other restaurants in other clusters and their rate is not bad, that means they have a lot of customer. so, the cluster 3 is a better choice if we want to invest our money in to one of their restaurants, based on the location strategy.
